# %% [markdown]
# # TUGAS 2

# %% [markdown]
# ## **Catatan Kelas**

# %%
import numpy as np
A=np.array([[8,9,1,19],[1,2,3,9],[2,1,1,5]])
print(A)
# Out:
# [[ 8  9  1 19]
#  [ 1  2  3  9]
#  [ 2  1  1  5]]

# %%
def RowSwap(A,k,l):
# =============================================================================
#     A is a NumPy array.  RowSwap will return duplicate array with rows
#     k and l swapped.
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        temp = B[k][j]
        B[k][j] = B[l][j]
        B[l][j] = temp

    return B

def RowScale(A,k,scale):
# =============================================================================
#     A is a NumPy array.  RowScale will return duplicate array with the
#     entries of row k multiplied by scale.
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        B[k][j] *= scale

    return B

def RowAdd(A,k,l,scale):
# =============================================================================
#     A is a numpy array.  RowAdd will return duplicate array with row
#     l modifed.  The new values will be the old values of row l added to
#     the values of row k, multiplied by scale.
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        B[l][j] += B[k][j]*scale

    return B

# %%
A1 = RowAdd (A,0,1,-2)
print(A1)
# Out:
# [[  8.   9.   1.  19.]
#  [-15. -16.   1. -29.]
#  [  2.   1.   1.   5.]]

# %%
A1 = RowSwap(A,0,1)
print(A1, '\n')
# Out:
# [[ 1.  2.  3.  9.]
#  [ 8.  9.  1. 19.]
#  [ 2.  1.  1.  5.]]

# %%
A2 = RowAdd(A1,0,1,-8)
print(A2,'\n')
# Out:
# [[  1.   2.   3.   9.]
#  [  0.  -7. -23. -53.]
#  [  2.   1.   1.   5.]]

# %%
A3 = RowAdd(A2,0,2,-2)
print(A3,'\n')
# Out:
# [[  1.   2.   3.   9.]
#  [  0.  -7. -23. -53.]
#  [  0.  -3.  -5. -13.]]

# %%
A4 = RowScale(A3,1,-1.0/7)
print(A4,'\n')
# Out:
# [[  1.           2.           3.           9.        ]
#  [ -0.           1.           3.28571429   7.57142857]
#  [  0.          -3.          -5.         -13.        ]]

# %%
A5 = RowAdd(A4,1,2,3)
print(A5,'\n')
# Out:
# [[ 1.          2.          3.          9.        ]
#  [-0.          1.          3.28571429  7.57142857]
#  [ 0.          0.          4.85714286  9.71428571]]

# %%
A6 = RowScale(A5,2,1/4.85714286)
print(A6,'\n')
# Out:
# [[ 1.          2.          3.          9.        ]
#  [-0.          1.          3.28571429  7.57142857]
#  [ 0.          0.          1.          2.        ]]

# %% [markdown]
# Persamaannya adalah
# $$
# x_1 + 2x_2 + 3x_3 = 9\\
# x_2 + 3.28571429x_3 = 7.57142857\\
# x_2 = 2$$

# %%
X3 = 2
print('X3 =',X3)
X2 = 7.57142857 - (3.28571429 *2)
print('X2 =', round(X2))
X1 = 9 - 2*X2 - 3*X3
print('X1 =',round(X1))
# Out:
# X3 = 2
# X2 = 1
# X1 = 1

# %% [markdown]
# ## **Tugas Membuat Gambar 3D**
#
# `%matplotlib inline` adalah magic command dalam Jupyter Notebook yang digunakan untuk menampilkan plot matplotlib secara langsung di dalam notebook, tanpa perlu memanggil `plt.show()` setiap kali membuat plot. Ini sangat berguna jika ingin membuat dan menampilkan plot secara interaktif dalam notebook.

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.8.3
# 1.26.4

# %% [markdown]
# ### A. Sample Dataset

# %%
# Persamaan

x3 = 3
x2 = 2
x1 = 1

# %% [markdown]
# ### B. Membuat Data untuk Plot

# %%
x1 = np.linspace(-5, 5, 100)
x2 = np.linspace(-5, 5, 100)
x1, x2 = np.meshgrid(x1, x2)
x3 = np.full_like(x1, x3)

print(x1.shape)
print(x2.shape)
print(x3.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# ### Visualisasi 3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x1, x2, x3, color='hotpink')

ax.set_title('3D Visualization')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')

plt.show()
